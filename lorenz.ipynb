# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 

# Initial parameters of state 
prandtl = 10 
rho = 25
beta = 8/3

# Define a function with the logic of the algo
def lorenz(x, y, z):
    x_dot = prandtl*(y - x)
    y_dot = rho*x - y - x*z
    z_dot = x*y - beta*z
    return x_dot, y_dot, z_dot

# Initialize variables, differential value and steps
dt = 0.01
num_steps = 5000

xs = np.empty(num_steps + 1)
ys = np.empty(num_steps + 1)
zs = np.empty(num_steps + 1)
xs[0], ys[0], zs[0] = (0., 6., 1.05)   


# Estimate partial derivatives at each point 
for i in range(num_steps):
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * dt)
    ys[i + 1] = ys[i] + (y_dot * dt)
    zs[i + 1] = zs[i] + (z_dot * dt)

# Render the plot 

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(xs, ys, zs, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()
# Out:
# C:\Users\luisg\AppData\Local\Temp\ipykernel_11764\3893421405.py:37: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# The Lorenz attractor has been used to model the behavior of prices over time and to study the underlying dynamics of financial markets. The attractor can be used to represent the behavior of market prices as a function of time, with the three dimensions of the attractor corresponding to different market variables such as the price of a particular asset, the volume of trades, and the level of market volatility.
#
# By studying the Lorenz attractor and the underlying Lorenz system of equations, it is possible to gain insight into the dynamics of financial markets and to make predictions about the future behavior of prices.
#
# This can be particularly useful for traders and investors who are trying to understand the forces that drive market behavior and to make informed decisions about when to buy or sell particular assets.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 

# Initial parameters of state 
prandtl = 10 
rho = 25
beta = 8/3

# Define a function with the logic of the algo
def lorenz(x, y, z):
    x_dot = prandtl*(y - x)
    y_dot = rho*x - y - x*z
    z_dot = x*y - beta*z
    return x_dot, y_dot, z_dot

# Initialize variables, differential value and steps
dt = 0.01
num_steps = 5000

xs = np.empty(num_steps + 1)
ys = np.empty(num_steps + 1)
zs = np.empty(num_steps + 1)
xs[0], ys[0], zs[0] = (0., 6., 1.05)   


# Estimate partial derivatives at each point 
for i in range(num_steps):
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * dt)
    ys[i + 1] = ys[i] + (y_dot * dt)
    zs[i + 1] = zs[i] + (z_dot * dt)

# Render the plot 

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(xs, ys, zs, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %% [markdown]
# This script defines a function `lorenz()` that takes three state variables (`x`, `y`, and `z`) as inputs and returns the partial derivatives of those variables with respect to time. The script then initializes the state variables to the values of `price`, `volatility`, and `volume` and uses the `lorenz()` function to estimate the partial derivatives at each point in time. Finally, the script creates a 3D plot to visualize the Lorenz attractor for the market product. You can adjust the values of the parameters `s`, `r`, and `b` to alter the shape of the attractor.

# %%
# Second version of the code. 
# !!! In this case we need proper dt and escale for the state variables.
# No negative values for state variables in here. 

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 

# Define the Lorenz system of differential equations
def lorenz(x, y, z, s=10, r=28, b=2.667):
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return x_dot, y_dot, z_dot

# Set the number of steps and time step size
num_steps = 10000
dt = 0.001

# Set the initial point 

price = 10
volatility = 0.1
volume = 500

# Initialize the state variables
xs = np.empty(num_steps + 1)
ys = np.empty(num_steps + 1)
zs = np.empty(num_steps + 1)
xs[0], ys[0], zs[0] = (price, volatility, volume)

# Estimate the partial derivatives at each point
for i in range(num_steps):
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * dt)
    ys[i + 1] = ys[i] + (y_dot * dt)
    zs[i + 1] = zs[i] + (z_dot * dt)

# Create a 3D plot to visualize the Lorenz attractor
fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot(xs, ys, zs, lw=0.5)
ax.set_xlabel("Price")
ax.set_ylabel("Volatility")
ax.set_zlabel("Volume")
ax.set_title("Lorenz Attractor for Market Product")

plt.show()
# Out:
# C:\Users\luisg\AppData\Local\Temp\ipykernel_11764\1975363637.py:39: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
